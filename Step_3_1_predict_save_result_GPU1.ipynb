# %% [markdown]
# ## 基础信息及配置

# %%
import sys; print('Python %s on %s' % (sys.version, sys.platform))

sys.path.extend(['./cnn_finetune','./lib'])

from load_cifar import load_cifar10_data, load_cifar100_data

import numpy as np; print('numpy:', np.__version__)
import sklearn; print('sklearn:', sklearn.__version__)
import tensorflow as tf; print('tensorflow', tf.__version__)
import keras; print('keras', keras.__version__)

import os
import tensorflow as tf
from keras.backend.tensorflow_backend import set_session

from lib.DataGenerator import DataGenerator

# set gpu visible environment variable
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
# Out:
# Python 3.5.2 (default, Nov 12 2018, 13:43:14)
# [GCC 5.4.0 20160609] on linux
# Using TensorFlow backend.
# numpy: 1.16.2
# sklearn: 0.20.3
# tensorflow 1.13.1
# keras 2.2.4

# %%
config = tf.ConfigProto()

# cpu
# config = tf.ConfigProto(intra_op_parallelism_threads=num_cores, inter_op_parallelism_threads=num_cores, allow_soft_placement=True, device_count={'CPU': 4})
    
# gpu allow_growth
config.gpu_options.allow_growth = True

# set memory limit of gpu
# config.gpu_options.per_process_gpu_memory_fraction = 0.5

set_session(tf.Session(config=config))

# %% [markdown]
# ## 加载模型

# %%
from keras.optimizers import SGD, Adam
from keras.callbacks import ModelCheckpoint, Callback, EarlyStopping, ReduceLROnPlateau, TensorBoard, CSVLogger


from cnn_finetune.resnet_152 import resnet152_model

# %%
batch_size = 16

# %%
def get_model(model_name):
    img_rows, img_cols = 224, 224 # Resolution of inputs
    channel = 3
    num_classes = 2019
    
    load_weights = False
    fine_tuning = False
    
    # Load our model
    model = model_name(img_rows, img_cols, channel, 
                              num_classes=num_classes, fine_tuning=fine_tuning, load_weights=load_weights)
    return model

# %% [markdown]
# ## 运用val数据集进行验证

# %%
def validate_val_dataset(model):
    adam = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-8, decay=0.0, amsgrad=False)
    model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['acc'])
    
    # load val dataset
    val_data_generator = DataGenerator(file_type='val', corp=True, batch_size=batch_size, shuffle=False)
    
    # evaluate the model
    valid_evaluate = model.evaluate_generator(val_data_generator, 
                                     steps = len(val_data_generator),
                                     workers=60, use_multiprocessing=True,
                                     verbose=1)
    print(valid_evaluate)
    return valid_evaluate

# %% [markdown]
# ## 预测test数据集

# %%
def predict(model, data_generator):
    predictions = model.predict_generator(data_generator, 
                                     steps = len(data_generator),
                                     workers=60, use_multiprocessing=True,
                                     verbose=1)
    filenames = data_generator.image_iterator.filenames
    
    return filenames, predictions

# %% [markdown]
# ## 预测过程

# %%
# !ls -l models
# Out:
# total 1259764
# -rw-r--r-- 1 root root 127695716 May  8 08:03 denesnet_161_20190508_2.9911_0.3629.hd5
# -rw-r--r-- 1 root root 127695716 May 12 12:29 denesnet_161_4.76-0.18-model.hd5
# -rw-r--r-- 1 root root 127393236 May 12 12:29 denesnet_161_4.76-0.18-weights.hd5
# -rw-r--r-- 1 root root  33552480 May  7 15:29 densenet121_weights_tf.h5
# drwxr-xr-x 4 root root      4096 May 14 03:44 densenet161
# drwxr-xr-x 3 root root      4096 May 12 04:49 densenet161_0512_val未收敛
# drwxr-xr-x 3 root root      4096 May 14 19:21 densenet161_former_3_GPU
# drwxr-xr-x 3 root root      4096 May  9 16:32 densenet161_train_1
# drwxr-xr-x 4 root root      4096 May  8 12:40 densenet161_val
# drwxr-xr-x 3 root root      4096 May 10 00:39 densenet161_val_2
# drwxr-xr-x 3 root root      4096 May 10 01:21 densenet161_val_3
# drwxr-xr-x 3 root root      4096 May 10 08:48 densenet161_verifiy
# -rw-r--r-- 1 root root 117815848 May  7 15:29 densenet161_weights_tf.h5
# -rw-r--r-- 1 root root  59218328 May  7 15:29 densenet169_weights_tf.h5
# drwxr-xr-x 4 1000 1000      4096 May 12 10:43 densenet_161_0.36
# drwxr-xr-x 3 root root      4096 May 19 12:14 densenet_161_211_load_imagenet_weight
# drwxr-xr-x 4 root root      4096 May  7 15:30 desnet_old_before_load_model
# -rw-r--r-- 1 root root 171805876 May  7 15:29 inception-v4_weights_tf_dim_ordering_tf_kernels.h5
# -rw-r--r-- 1 root root 178684328 May  7 15:29 resnet101_weights_tf.h5
# -rw-r--r-- 1 root root 243179624 May  7 15:29 resnet152_weights_tf.h5
# -rw-r--r-- 1 root root 102853048 May  7 15:29 resnet50_weights_tf_dim_ordering_tf_kernels.h5
# drwxr-xr-x 3 root root      4096 May 22 07:34 resnet_152
# drwxr-xr-x 3 root root      4096 May 23 05:01 resnet_152_1GPU
# drwxr-xr-x 3 root root      4096 May 22 01:52 resnet_152_GPU2
# drwxr-xr-x 3 root root      4096 May 21 14:25 resnet_152_GPU_2_3
# drwxr-xr-x 3 root root      4096 May 22 14:09 resnet_152_GPUs_2
# drwxr-xr-x 3 root root      4096 May 22 16:42 resnet_152_copy
# drwxr-xr-x 3 root root      4096 May 23 02:12 resnet_152_e03_2.9979
# drwxr-xr-x 3 root root      4096 May 22 15:34 resnet_152_multi_GPU
# drwxr-xr-x 3 root root      4096 May 23 04:42 resnet_152_test
# drwxr-xr-x 4 root root      4096 May  8 07:08 resnet_50

# %%
# !ls -l models/resnet_152

# %% [markdown]
# ### resnet 152

# %%
resnet152_predict_model = get_model(resnet152_model)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# load_weights False
# resnet152_model: classes: 2019 fine-tuning: False
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# data (InputLayer)               (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv1_zeropadding (ZeroPadding2 (None, 230, 230, 3)  0           data[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 112, 112, 64) 9408        conv1_zeropadding[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 112, 112, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# scale_conv1 (Scale)             (None, 112, 112, 64) 128         bn_conv1[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 112, 112, 64) 0           scale_conv1[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 55, 55, 64)   0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 55, 55, 64)   4096        pool1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 55, 55, 64)   256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# scale2a_branch2a (Scale)        (None, 55, 55, 64)   128         bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a_relu (Activation (None, 55, 55, 64)   0           scale2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b_zeropadding (Zer (None, 57, 57, 64)   0           res2a_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 55, 55, 64)   36864       res2a_branch2b_zeropadding[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 55, 55, 64)   256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# scale2a_branch2b (Scale)        (None, 55, 55, 64)   128         bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b_relu (Activation (None, 55, 55, 64)   0           scale2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 55, 55, 256)  16384       res2a_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 55, 55, 256)  16384       pool1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 55, 55, 256)  1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 55, 55, 256)  1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# scale2a_branch2c (Scale)        (None, 55, 55, 256)  512         bn2a_branch2c[0][0]
# __________________________________________________________________________________________________
# scale2a_branch1 (Scale)         (None, 55, 55, 256)  512         bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 55, 55, 256)  0           scale2a_branch2c[0][0]
#                                                                  scale2a_branch1[0][0]
# __________________________________________________________________________________________________
# res2a_relu (Activation)         (None, 55, 55, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 55, 55, 64)   16384       res2a_relu[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 55, 55, 64)   256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# scale2b_branch2a (Scale)        (None, 55, 55, 64)   128         bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a_relu (Activation (None, 55, 55, 64)   0           scale2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b_zeropadding (Zer (None, 57, 57, 64)   0           res2b_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 55, 55, 64)   36864       res2b_branch2b_zeropadding[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 55, 55, 64)   256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# scale2b_branch2b (Scale)        (None, 55, 55, 64)   128         bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b_relu (Activation (None, 55, 55, 64)   0           scale2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 55, 55, 256)  16384       res2b_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 55, 55, 256)  1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# scale2b_branch2c (Scale)        (None, 55, 55, 256)  512         bn2b_branch2c[0][0]
# __________________________________________________________________________________________________
# res2b (Add)                     (None, 55, 55, 256)  0           scale2b_branch2c[0][0]
#                                                                  res2a_relu[0][0]
# __________________________________________________________________________________________________
# res2b_relu (Activation)         (None, 55, 55, 256)  0           res2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 55, 55, 64)   16384       res2b_relu[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 55, 55, 64)   256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# scale2c_branch2a (Scale)        (None, 55, 55, 64)   128         bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a_relu (Activation (None, 55, 55, 64)   0           scale2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b_zeropadding (Zer (None, 57, 57, 64)   0           res2c_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 55, 55, 64)   36864       res2c_branch2b_zeropadding[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 55, 55, 64)   256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# scale2c_branch2b (Scale)        (None, 55, 55, 64)   128         bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b_relu (Activation (None, 55, 55, 64)   0           scale2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 55, 55, 256)  16384       res2c_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 55, 55, 256)  1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# scale2c_branch2c (Scale)        (None, 55, 55, 256)  512         bn2c_branch2c[0][0]
# __________________________________________________________________________________________________
# res2c (Add)                     (None, 55, 55, 256)  0           scale2c_branch2c[0][0]
#                                                                  res2b_relu[0][0]
# __________________________________________________________________________________________________
# res2c_relu (Activation)         (None, 55, 55, 256)  0           res2c[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 28, 28, 128)  32768       res2c_relu[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 28, 28, 128)  512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# scale3a_branch2a (Scale)        (None, 28, 28, 128)  256         bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a_relu (Activation (None, 28, 28, 128)  0           scale3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b_zeropadding (Zer (None, 30, 30, 128)  0           res3a_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 28, 28, 128)  147456      res3a_branch2b_zeropadding[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 28, 28, 128)  512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# scale3a_branch2b (Scale)        (None, 28, 28, 128)  256         bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b_relu (Activation (None, 28, 28, 128)  0           scale3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 28, 28, 512)  65536       res3a_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 28, 28, 512)  131072      res2c_relu[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 28, 28, 512)  2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 28, 28, 512)  2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# scale3a_branch2c (Scale)        (None, 28, 28, 512)  1024        bn3a_branch2c[0][0]
# __________________________________________________________________________________________________
# scale3a_branch1 (Scale)         (None, 28, 28, 512)  1024        bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 28, 28, 512)  0           scale3a_branch2c[0][0]
#                                                                  scale3a_branch1[0][0]
# __________________________________________________________________________________________________
# res3a_relu (Activation)         (None, 28, 28, 512)  0           add_2[0][0]
# __________________________________________________________________________________________________
# res3b1_branch2a (Conv2D)        (None, 28, 28, 128)  65536       res3a_relu[0][0]
# __________________________________________________________________________________________________
# bn3b1_branch2a (BatchNormalizat (None, 28, 28, 128)  512         res3b1_branch2a[0][0]
# __________________________________________________________________________________________________
# scale3b1_branch2a (Scale)       (None, 28, 28, 128)  256         bn3b1_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b1_branch2a_relu (Activatio (None, 28, 28, 128)  0           scale3b1_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b1_branch2b_zeropadding (Ze (None, 30, 30, 128)  0           res3b1_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res3b1_branch2b (Conv2D)        (None, 28, 28, 128)  147456      res3b1_branch2b_zeropadding[0][0]
# __________________________________________________________________________________________________
# bn3b1_branch2b (BatchNormalizat (None, 28, 28, 128)  512         res3b1_branch2b[0][0]
# __________________________________________________________________________________________________
# scale3b1_branch2b (Scale)       (None, 28, 28, 128)  256         bn3b1_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b1_branch2b_relu (Activatio (None, 28, 28, 128)  0           scale3b1_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b1_branch2c (Conv2D)        (None, 28, 28, 512)  65536       res3b1_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn3b1_branch2c (BatchNormalizat (None, 28, 28, 512)  2048        res3b1_branch2c[0][0]
# __________________________________________________________________________________________________
# scale3b1_branch2c (Scale)       (None, 28, 28, 512)  1024        bn3b1_branch2c[0][0]
# __________________________________________________________________________________________________
# res3b1 (Add)                    (None, 28, 28, 512)  0           scale3b1_branch2c[0][0]
#                                                                  res3a_relu[0][0]
# __________________________________________________________________________________________________
# res3b1_relu (Activation)        (None, 28, 28, 512)  0           res3b1[0][0]
# __________________________________________________________________________________________________
# res3b2_branch2a (Conv2D)        (None, 28, 28, 128)  65536       res3b1_relu[0][0]
# __________________________________________________________________________________________________
# bn3b2_branch2a (BatchNormalizat (None, 28, 28, 128)  512         res3b2_branch2a[0][0]
# __________________________________________________________________________________________________
# scale3b2_branch2a (Scale)       (None, 28, 28, 128)  256         bn3b2_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b2_branch2a_relu (Activatio (None, 28, 28, 128)  0           scale3b2_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b2_branch2b_zeropadding (Ze (None, 30, 30, 128)  0           res3b2_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res3b2_branch2b (Conv2D)        (None, 28, 28, 128)  147456      res3b2_branch2b_zeropadding[0][0]
# __________________________________________________________________________________________________
# bn3b2_branch2b (BatchNormalizat (None, 28, 28, 128)  512         res3b2_branch2b[0][0]
# __________________________________________________________________________________________________
# scale3b2_branch2b (Scale)       (None, 28, 28, 128)  256         bn3b2_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b2_branch2b_relu (Activatio (None, 28, 28, 128)  0           scale3b2_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b2_branch2c (Conv2D)        (None, 28, 28, 512)  65536       res3b2_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn3b2_branch2c (BatchNormalizat (None, 28, 28, 512)  2048        res3b2_branch2c[0][0]
# __________________________________________________________________________________________________
# scale3b2_branch2c (Scale)       (None, 28, 28, 512)  1024        bn3b2_branch2c[0][0]
# __________________________________________________________________________________________________
# res3b2 (Add)                    (None, 28, 28, 512)  0           scale3b2_branch2c[0][0]
#                                                                  res3b1_relu[0][0]
# __________________________________________________________________________________________________
# res3b2_relu (Activation)        (None, 28, 28, 512)  0           res3b2[0][0]
# __________________________________________________________________________________________________
# res3b3_branch2a (Conv2D)        (None, 28, 28, 128)  65536       res3b2_relu[0][0]
# __________________________________________________________________________________________________
# bn3b3_branch2a (BatchNormalizat (None, 28, 28, 128)  512         res3b3_branch2a[0][0]
# __________________________________________________________________________________________________
# scale3b3_branch2a (Scale)       (None, 28, 28, 128)  256         bn3b3_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b3_branch2a_relu (Activatio (None, 28, 28, 128)  0           scale3b3_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b3_branch2b_zeropadding (Ze (None, 30, 30, 128)  0           res3b3_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res3b3_branch2b (Conv2D)        (None, 28, 28, 128)  147456      res3b3_branch2b_zeropadding[0][0]
# __________________________________________________________________________________________________
# bn3b3_branch2b (BatchNormalizat (None, 28, 28, 128)  512         res3b3_branch2b[0][0]
# __________________________________________________________________________________________________
# scale3b3_branch2b (Scale)       (None, 28, 28, 128)  256         bn3b3_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b3_branch2b_relu (Activatio (None, 28, 28, 128)  0           scale3b3_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b3_branch2c (Conv2D)        (None, 28, 28, 512)  65536       res3b3_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn3b3_branch2c (BatchNormalizat (None, 28, 28, 512)  2048        res3b3_branch2c[0][0]
# __________________________________________________________________________________________________
# scale3b3_branch2c (Scale)       (None, 28, 28, 512)  1024        bn3b3_branch2c[0][0]
# __________________________________________________________________________________________________
# res3b3 (Add)                    (None, 28, 28, 512)  0           scale3b3_branch2c[0][0]
#                                                                  res3b2_relu[0][0]
# __________________________________________________________________________________________________
# res3b3_relu (Activation)        (None, 28, 28, 512)  0           res3b3[0][0]
# __________________________________________________________________________________________________
# res3b4_branch2a (Conv2D)        (None, 28, 28, 128)  65536       res3b3_relu[0][0]
# __________________________________________________________________________________________________
# bn3b4_branch2a (BatchNormalizat (None, 28, 28, 128)  512         res3b4_branch2a[0][0]
# __________________________________________________________________________________________________
# scale3b4_branch2a (Scale)       (None, 28, 28, 128)  256         bn3b4_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b4_branch2a_relu (Activatio (None, 28, 28, 128)  0           scale3b4_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b4_branch2b_zeropadding (Ze (None, 30, 30, 128)  0           res3b4_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res3b4_branch2b (Conv2D)        (None, 28, 28, 128)  147456      res3b4_branch2b_zeropadding[0][0]
# __________________________________________________________________________________________________
# bn3b4_branch2b (BatchNormalizat (None, 28, 28, 128)  512         res3b4_branch2b[0][0]
# __________________________________________________________________________________________________
# scale3b4_branch2b (Scale)       (None, 28, 28, 128)  256         bn3b4_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b4_branch2b_relu (Activatio (None, 28, 28, 128)  0           scale3b4_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b4_branch2c (Conv2D)        (None, 28, 28, 512)  65536       res3b4_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn3b4_branch2c (BatchNormalizat (None, 28, 28, 512)  2048        res3b4_branch2c[0][0]
# __________________________________________________________________________________________________
# scale3b4_branch2c (Scale)       (None, 28, 28, 512)  1024        bn3b4_branch2c[0][0]
# __________________________________________________________________________________________________
# res3b4 (Add)                    (None, 28, 28, 512)  0           scale3b4_branch2c[0][0]
#                                                                  res3b3_relu[0][0]
# __________________________________________________________________________________________________
# res3b4_relu (Activation)        (None, 28, 28, 512)  0           res3b4[0][0]
# __________________________________________________________________________________________________
# res3b5_branch2a (Conv2D)        (None, 28, 28, 128)  65536       res3b4_relu[0][0]
# __________________________________________________________________________________________________
# bn3b5_branch2a (BatchNormalizat (None, 28, 28, 128)  512         res3b5_branch2a[0][0]
# __________________________________________________________________________________________________
# scale3b5_branch2a (Scale)       (None, 28, 28, 128)  256         bn3b5_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b5_branch2a_relu (Activatio (None, 28, 28, 128)  0           scale3b5_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b5_branch2b_zeropadding (Ze (None, 30, 30, 128)  0           res3b5_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res3b5_branch2b (Conv2D)        (None, 28, 28, 128)  147456      res3b5_branch2b_zeropadding[0][0]
# __________________________________________________________________________________________________
# bn3b5_branch2b (BatchNormalizat (None, 28, 28, 128)  512         res3b5_branch2b[0][0]
# __________________________________________________________________________________________________
# scale3b5_branch2b (Scale)       (None, 28, 28, 128)  256         bn3b5_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b5_branch2b_relu (Activatio (None, 28, 28, 128)  0           scale3b5_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b5_branch2c (Conv2D)        (None, 28, 28, 512)  65536       res3b5_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn3b5_branch2c (BatchNormalizat (None, 28, 28, 512)  2048        res3b5_branch2c[0][0]
# __________________________________________________________________________________________________
# scale3b5_branch2c (Scale)       (None, 28, 28, 512)  1024        bn3b5_branch2c[0][0]
# __________________________________________________________________________________________________
# res3b5 (Add)                    (None, 28, 28, 512)  0           scale3b5_branch2c[0][0]
#                                                                  res3b4_relu[0][0]
# __________________________________________________________________________________________________
# res3b5_relu (Activation)        (None, 28, 28, 512)  0           res3b5[0][0]
# __________________________________________________________________________________________________
# res3b6_branch2a (Conv2D)        (None, 28, 28, 128)  65536       res3b5_relu[0][0]
# __________________________________________________________________________________________________
# bn3b6_branch2a (BatchNormalizat (None, 28, 28, 128)  512         res3b6_branch2a[0][0]
# __________________________________________________________________________________________________
# scale3b6_branch2a (Scale)       (None, 28, 28, 128)  256         bn3b6_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b6_branch2a_relu (Activatio (None, 28, 28, 128)  0           scale3b6_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b6_branch2b_zeropadding (Ze (None, 30, 30, 128)  0           res3b6_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res3b6_branch2b (Conv2D)        (None, 28, 28, 128)  147456      res3b6_branch2b_zeropadding[0][0]
# __________________________________________________________________________________________________
# bn3b6_branch2b (BatchNormalizat (None, 28, 28, 128)  512         res3b6_branch2b[0][0]
# __________________________________________________________________________________________________
# scale3b6_branch2b (Scale)       (None, 28, 28, 128)  256         bn3b6_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b6_branch2b_relu (Activatio (None, 28, 28, 128)  0           scale3b6_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b6_branch2c (Conv2D)        (None, 28, 28, 512)  65536       res3b6_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn3b6_branch2c (BatchNormalizat (None, 28, 28, 512)  2048        res3b6_branch2c[0][0]
# __________________________________________________________________________________________________
# scale3b6_branch2c (Scale)       (None, 28, 28, 512)  1024        bn3b6_branch2c[0][0]
# __________________________________________________________________________________________________
# res3b6 (Add)                    (None, 28, 28, 512)  0           scale3b6_branch2c[0][0]
#                                                                  res3b5_relu[0][0]
# __________________________________________________________________________________________________
# res3b6_relu (Activation)        (None, 28, 28, 512)  0           res3b6[0][0]
# __________________________________________________________________________________________________
# res3b7_branch2a (Conv2D)        (None, 28, 28, 128)  65536       res3b6_relu[0][0]
# __________________________________________________________________________________________________
# bn3b7_branch2a (BatchNormalizat (None, 28, 28, 128)  512         res3b7_branch2a[0][0]
# __________________________________________________________________________________________________
# scale3b7_branch2a (Scale)       (None, 28, 28, 128)  256         bn3b7_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b7_branch2a_relu (Activatio (None, 28, 28, 128)  0           scale3b7_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b7_branch2b_zeropadding (Ze (None, 30, 30, 128)  0           res3b7_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res3b7_branch2b (Conv2D)        (None, 28, 28, 128)  147456      res3b7_branch2b_zeropadding[0][0]
# __________________________________________________________________________________________________
# bn3b7_branch2b (BatchNormalizat (None, 28, 28, 128)  512         res3b7_branch2b[0][0]
# __________________________________________________________________________________________________
# scale3b7_branch2b (Scale)       (None, 28, 28, 128)  256         bn3b7_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b7_branch2b_relu (Activatio (None, 28, 28, 128)  0           scale3b7_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b7_branch2c (Conv2D)        (None, 28, 28, 512)  65536       res3b7_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn3b7_branch2c (BatchNormalizat (None, 28, 28, 512)  2048        res3b7_branch2c[0][0]
# __________________________________________________________________________________________________
# scale3b7_branch2c (Scale)       (None, 28, 28, 512)  1024        bn3b7_branch2c[0][0]
# __________________________________________________________________________________________________
# res3b7 (Add)                    (None, 28, 28, 512)  0           scale3b7_branch2c[0][0]
#                                                                  res3b6_relu[0][0]
# __________________________________________________________________________________________________
# res3b7_relu (Activation)        (None, 28, 28, 512)  0           res3b7[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 14, 14, 256)  131072      res3b7_relu[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# scale4a_branch2a (Scale)        (None, 14, 14, 256)  512         bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a_relu (Activation (None, 14, 14, 256)  0           scale4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b_zeropadding (Zer (None, 16, 16, 256)  0           res4a_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 14, 14, 256)  589824      res4a_branch2b_zeropadding[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# scale4a_branch2b (Scale)        (None, 14, 14, 256)  512         bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b_relu (Activation (None, 14, 14, 256)  0           scale4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 14, 14, 1024) 262144      res4a_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 14, 14, 1024) 524288      res3b7_relu[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 14, 14, 1024) 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# scale4a_branch2c (Scale)        (None, 14, 14, 1024) 2048        bn4a_branch2c[0][0]
# __________________________________________________________________________________________________
# scale4a_branch1 (Scale)         (None, 14, 14, 1024) 2048        bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 14, 14, 1024) 0           scale4a_branch2c[0][0]
#                                                                  scale4a_branch1[0][0]
# __________________________________________________________________________________________________
# res4a_relu (Activation)         (None, 14, 14, 1024) 0           add_3[0][0]
# __________________________________________________________________________________________________
# res4b1_branch2a (Conv2D)        (None, 14, 14, 256)  262144      res4a_relu[0][0]
# __________________________________________________________________________________________________
# bn4b1_branch2a (BatchNormalizat (None, 14, 14, 256)  1024        res4b1_branch2a[0][0]
# __________________________________________________________________________________________________
# scale4b1_branch2a (Scale)       (None, 14, 14, 256)  512         bn4b1_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b1_branch2a_relu (Activatio (None, 14, 14, 256)  0           scale4b1_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b1_branch2b_zeropadding (Ze (None, 16, 16, 256)  0           res4b1_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4b1_branch2b (Conv2D)        (None, 14, 14, 256)  589824      res4b1_branch2b_zeropadding[0][0]
# __________________________________________________________________________________________________
# bn4b1_branch2b (BatchNormalizat (None, 14, 14, 256)  1024        res4b1_branch2b[0][0]
# __________________________________________________________________________________________________
# scale4b1_branch2b (Scale)       (None, 14, 14, 256)  512         bn4b1_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b1_branch2b_relu (Activatio (None, 14, 14, 256)  0           scale4b1_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b1_branch2c (Conv2D)        (None, 14, 14, 1024) 262144      res4b1_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4b1_branch2c (BatchNormalizat (None, 14, 14, 1024) 4096        res4b1_branch2c[0][0]
# __________________________________________________________________________________________________
# scale4b1_branch2c (Scale)       (None, 14, 14, 1024) 2048        bn4b1_branch2c[0][0]
# __________________________________________________________________________________________________
# res4b1 (Add)                    (None, 14, 14, 1024) 0           scale4b1_branch2c[0][0]
#                                                                  res4a_relu[0][0]
# __________________________________________________________________________________________________
# res4b1_relu (Activation)        (None, 14, 14, 1024) 0           res4b1[0][0]
# __________________________________________________________________________________________________
# res4b2_branch2a (Conv2D)        (None, 14, 14, 256)  262144      res4b1_relu[0][0]
# __________________________________________________________________________________________________
# bn4b2_branch2a (BatchNormalizat (None, 14, 14, 256)  1024        res4b2_branch2a[0][0]
# __________________________________________________________________________________________________
# scale4b2_branch2a (Scale)       (None, 14, 14, 256)  512         bn4b2_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b2_branch2a_relu (Activatio (None, 14, 14, 256)  0           scale4b2_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b2_branch2b_zeropadding (Ze (None, 16, 16, 256)  0           res4b2_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4b2_branch2b (Conv2D)        (None, 14, 14, 256)  589824      res4b2_branch2b_zeropadding[0][0]
# __________________________________________________________________________________________________
# bn4b2_branch2b (BatchNormalizat (None, 14, 14, 256)  1024        res4b2_branch2b[0][0]
# __________________________________________________________________________________________________
# scale4b2_branch2b (Scale)       (None, 14, 14, 256)  512         bn4b2_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b2_branch2b_relu (Activatio (None, 14, 14, 256)  0           scale4b2_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b2_branch2c (Conv2D)        (None, 14, 14, 1024) 262144      res4b2_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4b2_branch2c (BatchNormalizat (None, 14, 14, 1024) 4096        res4b2_branch2c[0][0]
# __________________________________________________________________________________________________
# scale4b2_branch2c (Scale)       (None, 14, 14, 1024) 2048        bn4b2_branch2c[0][0]
# __________________________________________________________________________________________________
# res4b2 (Add)                    (None, 14, 14, 1024) 0           scale4b2_branch2c[0][0]
#                                                                  res4b1_relu[0][0]
# __________________________________________________________________________________________________
# res4b2_relu (Activation)        (None, 14, 14, 1024) 0           res4b2[0][0]
# __________________________________________________________________________________________________
# res4b3_branch2a (Conv2D)        (None, 14, 14, 256)  262144      res4b2_relu[0][0]
# __________________________________________________________________________________________________
# bn4b3_branch2a (BatchNormalizat (None, 14, 14, 256)  1024        res4b3_branch2a[0][0]
# __________________________________________________________________________________________________
# scale4b3_branch2a (Scale)       (None, 14, 14, 256)  512         bn4b3_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b3_branch2a_relu (Activatio (None, 14, 14, 256)  0           scale4b3_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b3_branch2b_zeropadding (Ze (None, 16, 16, 256)  0           res4b3_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4b3_branch2b (Conv2D)        (None, 14, 14, 256)  589824      res4b3_branch2b_zeropadding[0][0]
# __________________________________________________________________________________________________
# bn4b3_branch2b (BatchNormalizat (None, 14, 14, 256)  1024        res4b3_branch2b[0][0]
# __________________________________________________________________________________________________
# scale4b3_branch2b (Scale)       (None, 14, 14, 256)  512         bn4b3_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b3_branch2b_relu (Activatio (None, 14, 14, 256)  0           scale4b3_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b3_branch2c (Conv2D)        (None, 14, 14, 1024) 262144      res4b3_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4b3_branch2c (BatchNormalizat (None, 14, 14, 1024) 4096        res4b3_branch2c[0][0]
# __________________________________________________________________________________________________
# scale4b3_branch2c (Scale)       (None, 14, 14, 1024) 2048        bn4b3_branch2c[0][0]
# __________________________________________________________________________________________________
# res4b3 (Add)                    (None, 14, 14, 1024) 0           scale4b3_branch2c[0][0]
#                                                                  res4b2_relu[0][0]
# __________________________________________________________________________________________________
# res4b3_relu (Activation)        (None, 14, 14, 1024) 0           res4b3[0][0]
# __________________________________________________________________________________________________
# res4b4_branch2a (Conv2D)        (None, 14, 14, 256)  262144      res4b3_relu[0][0]
# __________________________________________________________________________________________________
# bn4b4_branch2a (BatchNormalizat (None, 14, 14, 256)  1024        res4b4_branch2a[0][0]
# __________________________________________________________________________________________________
# scale4b4_branch2a (Scale)       (None, 14, 14, 256)  512         bn4b4_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b4_branch2a_relu (Activatio (None, 14, 14, 256)  0           scale4b4_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b4_branch2b_zeropadding (Ze (None, 16, 16, 256)  0           res4b4_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4b4_branch2b (Conv2D)        (None, 14, 14, 256)  589824      res4b4_branch2b_zeropadding[0][0]
# ...
# __________________________________________________________________________________________________
# res4b34_branch2a (Conv2D)       (None, 14, 14, 256)  262144      res4b33_relu[0][0]
# __________________________________________________________________________________________________
# bn4b34_branch2a (BatchNormaliza (None, 14, 14, 256)  1024        res4b34_branch2a[0][0]
# __________________________________________________________________________________________________
# scale4b34_branch2a (Scale)      (None, 14, 14, 256)  512         bn4b34_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b34_branch2a_relu (Activati (None, 14, 14, 256)  0           scale4b34_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b34_branch2b_zeropadding (Z (None, 16, 16, 256)  0           res4b34_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4b34_branch2b (Conv2D)       (None, 14, 14, 256)  589824      res4b34_branch2b_zeropadding[0][0
# __________________________________________________________________________________________________
# bn4b34_branch2b (BatchNormaliza (None, 14, 14, 256)  1024        res4b34_branch2b[0][0]
# __________________________________________________________________________________________________
# scale4b34_branch2b (Scale)      (None, 14, 14, 256)  512         bn4b34_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b34_branch2b_relu (Activati (None, 14, 14, 256)  0           scale4b34_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b34_branch2c (Conv2D)       (None, 14, 14, 1024) 262144      res4b34_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4b34_branch2c (BatchNormaliza (None, 14, 14, 1024) 4096        res4b34_branch2c[0][0]
# __________________________________________________________________________________________________
# scale4b34_branch2c (Scale)      (None, 14, 14, 1024) 2048        bn4b34_branch2c[0][0]
# __________________________________________________________________________________________________
# res4b34 (Add)                   (None, 14, 14, 1024) 0           scale4b34_branch2c[0][0]
#                                                                  res4b33_relu[0][0]
# __________________________________________________________________________________________________
# res4b34_relu (Activation)       (None, 14, 14, 1024) 0           res4b34[0][0]
# __________________________________________________________________________________________________
# res4b35_branch2a (Conv2D)       (None, 14, 14, 256)  262144      res4b34_relu[0][0]
# __________________________________________________________________________________________________
# bn4b35_branch2a (BatchNormaliza (None, 14, 14, 256)  1024        res4b35_branch2a[0][0]
# __________________________________________________________________________________________________
# scale4b35_branch2a (Scale)      (None, 14, 14, 256)  512         bn4b35_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b35_branch2a_relu (Activati (None, 14, 14, 256)  0           scale4b35_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b35_branch2b_zeropadding (Z (None, 16, 16, 256)  0           res4b35_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4b35_branch2b (Conv2D)       (None, 14, 14, 256)  589824      res4b35_branch2b_zeropadding[0][0
# __________________________________________________________________________________________________
# bn4b35_branch2b (BatchNormaliza (None, 14, 14, 256)  1024        res4b35_branch2b[0][0]
# __________________________________________________________________________________________________
# scale4b35_branch2b (Scale)      (None, 14, 14, 256)  512         bn4b35_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b35_branch2b_relu (Activati (None, 14, 14, 256)  0           scale4b35_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b35_branch2c (Conv2D)       (None, 14, 14, 1024) 262144      res4b35_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4b35_branch2c (BatchNormaliza (None, 14, 14, 1024) 4096        res4b35_branch2c[0][0]
# __________________________________________________________________________________________________
# scale4b35_branch2c (Scale)      (None, 14, 14, 1024) 2048        bn4b35_branch2c[0][0]
# __________________________________________________________________________________________________
# res4b35 (Add)                   (None, 14, 14, 1024) 0           scale4b35_branch2c[0][0]
#                                                                  res4b34_relu[0][0]
# __________________________________________________________________________________________________
# res4b35_relu (Activation)       (None, 14, 14, 1024) 0           res4b35[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, 7, 7, 512)    524288      res4b35_relu[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, 7, 7, 512)    2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# scale5a_branch2a (Scale)        (None, 7, 7, 512)    1024        bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a_relu (Activation (None, 7, 7, 512)    0           scale5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b_zeropadding (Zer (None, 9, 9, 512)    0           res5a_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, 7, 7, 512)    2359296     res5a_branch2b_zeropadding[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, 7, 7, 512)    2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# scale5a_branch2b (Scale)        (None, 7, 7, 512)    1024        bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b_relu (Activation (None, 7, 7, 512)    0           scale5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, 7, 7, 2048)   1048576     res5a_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, 7, 7, 2048)   2097152     res4b35_relu[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, 7, 7, 2048)   8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, 7, 7, 2048)   8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# scale5a_branch2c (Scale)        (None, 7, 7, 2048)   4096        bn5a_branch2c[0][0]
# __________________________________________________________________________________________________
# scale5a_branch1 (Scale)         (None, 7, 7, 2048)   4096        bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 7, 7, 2048)   0           scale5a_branch2c[0][0]
#                                                                  scale5a_branch1[0][0]
# __________________________________________________________________________________________________
# res5a_relu (Activation)         (None, 7, 7, 2048)   0           add_4[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, 7, 7, 512)    1048576     res5a_relu[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, 7, 7, 512)    2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# scale5b_branch2a (Scale)        (None, 7, 7, 512)    1024        bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a_relu (Activation (None, 7, 7, 512)    0           scale5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b_zeropadding (Zer (None, 9, 9, 512)    0           res5b_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, 7, 7, 512)    2359296     res5b_branch2b_zeropadding[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, 7, 7, 512)    2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# scale5b_branch2b (Scale)        (None, 7, 7, 512)    1024        bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b_relu (Activation (None, 7, 7, 512)    0           scale5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, 7, 7, 2048)   1048576     res5b_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, 7, 7, 2048)   8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# scale5b_branch2c (Scale)        (None, 7, 7, 2048)   4096        bn5b_branch2c[0][0]
# __________________________________________________________________________________________________
# res5b (Add)                     (None, 7, 7, 2048)   0           scale5b_branch2c[0][0]
#                                                                  res5a_relu[0][0]
# __________________________________________________________________________________________________
# res5b_relu (Activation)         (None, 7, 7, 2048)   0           res5b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, 7, 7, 512)    1048576     res5b_relu[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, 7, 7, 512)    2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# scale5c_branch2a (Scale)        (None, 7, 7, 512)    1024        bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a_relu (Activation (None, 7, 7, 512)    0           scale5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b_zeropadding (Zer (None, 9, 9, 512)    0           res5c_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, 7, 7, 512)    2359296     res5c_branch2b_zeropadding[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, 7, 7, 512)    2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# scale5c_branch2b (Scale)        (None, 7, 7, 512)    1024        bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b_relu (Activation (None, 7, 7, 512)    0           scale5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, 7, 7, 2048)   1048576     res5c_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, 7, 7, 2048)   8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# scale5c_branch2c (Scale)        (None, 7, 7, 2048)   4096        bn5c_branch2c[0][0]
# __________________________________________________________________________________________________
# res5c (Add)                     (None, 7, 7, 2048)   0           scale5c_branch2c[0][0]
#                                                                  res5b_relu[0][0]
# __________________________________________________________________________________________________
# res5c_relu (Activation)         (None, 7, 7, 2048)   0           res5c[0][0]
# __________________________________________________________________________________________________
# avg_pool (AveragePooling2D)     (None, 1, 1, 2048)   0           res5c_relu[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 2048)         0           avg_pool[0][0]
# __________________________________________________________________________________________________
# fc8 (Dense)                     (None, 2019)         4136931     flatten_1[0][0]
# ==================================================================================================
# Total params: 62,583,587
# Trainable params: 62,432,163
# Non-trainable params: 151,424
# __________________________________________________________________________________________________
# ----------------------------------------------------------------------------------------------------

# %%
# load weight
weights_path="./models/imaterialist-e01-2.3851.hd5"
resnet152_predict_model.load_weights(weights_path)

# %%
validate_val_dataset(resnet152_predict_model)
# Out:
# Found 10095 images belonging to 2019 classes.
# 631/631 [==============================] - 132s 209ms/step
# [2.3850735998082833, 0.43605745419409675]
# [2.3850735998082833, 0.43605745419409675]

# %%
test_data_generator = DataGenerator(file_type='predict', corp=True, batch_size=batch_size, shuffle=False)
# Out:
# Found 90833 images belonging to 1 classes.

# %%
rest152_filenames, rest152_pred = predict(resnet152_predict_model, test_data_generator)
# Out:
# 5678/5678 [==============================] - 692s 122ms/step

# %%
import os
directory = "./submissions/middle/resnet152/imaterialist-e01-2.3851"
os.makedirs(directory)
np.save(directory+"/resnet152_pred.npy",rest152_pred)
np.save(directory+"/resnet152_filenames.npy",rest152_filenames)

# %% [markdown]
# ### densenet 161

# %%
from cnn_finetune.densenet161_weights_path import densenet161_model

densenet161_predict_model = get_model(densenet161_model)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# dense161_model: classes: 2019 fine-tuning: False
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# data (InputLayer)               (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv1_zeropadding (ZeroPadding2 (None, 230, 230, 3)  0           data[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 112, 112, 96) 14112       conv1_zeropadding[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 96) 384         conv1[0][0]
# __________________________________________________________________________________________________
# conv1_scale (Scale)             (None, 112, 112, 96) 192         conv1_bn[0][0]
# __________________________________________________________________________________________________
# relu1 (Activation)              (None, 112, 112, 96) 0           conv1_scale[0][0]
# __________________________________________________________________________________________________
# pool1_zeropadding (ZeroPadding2 (None, 114, 114, 96) 0           relu1[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 56, 56, 96)   0           pool1_zeropadding[0][0]
# __________________________________________________________________________________________________
# conv2_1_x1_bn (BatchNormalizati (None, 56, 56, 96)   384         pool1[0][0]
# __________________________________________________________________________________________________
# conv2_1_x1_scale (Scale)        (None, 56, 56, 96)   192         conv2_1_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu2_1_x1 (Activation)         (None, 56, 56, 96)   0           conv2_1_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv2_1_x1 (Conv2D)             (None, 56, 56, 192)  18432       relu2_1_x1[0][0]
# __________________________________________________________________________________________________
# conv2_1_x2_bn (BatchNormalizati (None, 56, 56, 192)  768         conv2_1_x1[0][0]
# __________________________________________________________________________________________________
# conv2_1_x2_scale (Scale)        (None, 56, 56, 192)  384         conv2_1_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu2_1_x2 (Activation)         (None, 56, 56, 192)  0           conv2_1_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv2_1_x2_zeropadding (ZeroPad (None, 58, 58, 192)  0           relu2_1_x2[0][0]
# __________________________________________________________________________________________________
# conv2_1_x2 (Conv2D)             (None, 56, 56, 48)   82944       conv2_1_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_2_1 (Concatenate)        (None, 56, 56, 144)  0           pool1[0][0]
#                                                                  conv2_1_x2[0][0]
# __________________________________________________________________________________________________
# conv2_2_x1_bn (BatchNormalizati (None, 56, 56, 144)  576         concat_2_1[0][0]
# __________________________________________________________________________________________________
# conv2_2_x1_scale (Scale)        (None, 56, 56, 144)  288         conv2_2_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu2_2_x1 (Activation)         (None, 56, 56, 144)  0           conv2_2_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv2_2_x1 (Conv2D)             (None, 56, 56, 192)  27648       relu2_2_x1[0][0]
# __________________________________________________________________________________________________
# conv2_2_x2_bn (BatchNormalizati (None, 56, 56, 192)  768         conv2_2_x1[0][0]
# __________________________________________________________________________________________________
# conv2_2_x2_scale (Scale)        (None, 56, 56, 192)  384         conv2_2_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu2_2_x2 (Activation)         (None, 56, 56, 192)  0           conv2_2_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv2_2_x2_zeropadding (ZeroPad (None, 58, 58, 192)  0           relu2_2_x2[0][0]
# __________________________________________________________________________________________________
# conv2_2_x2 (Conv2D)             (None, 56, 56, 48)   82944       conv2_2_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_2_2 (Concatenate)        (None, 56, 56, 192)  0           concat_2_1[0][0]
#                                                                  conv2_2_x2[0][0]
# __________________________________________________________________________________________________
# conv2_3_x1_bn (BatchNormalizati (None, 56, 56, 192)  768         concat_2_2[0][0]
# __________________________________________________________________________________________________
# conv2_3_x1_scale (Scale)        (None, 56, 56, 192)  384         conv2_3_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu2_3_x1 (Activation)         (None, 56, 56, 192)  0           conv2_3_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv2_3_x1 (Conv2D)             (None, 56, 56, 192)  36864       relu2_3_x1[0][0]
# __________________________________________________________________________________________________
# conv2_3_x2_bn (BatchNormalizati (None, 56, 56, 192)  768         conv2_3_x1[0][0]
# __________________________________________________________________________________________________
# conv2_3_x2_scale (Scale)        (None, 56, 56, 192)  384         conv2_3_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu2_3_x2 (Activation)         (None, 56, 56, 192)  0           conv2_3_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv2_3_x2_zeropadding (ZeroPad (None, 58, 58, 192)  0           relu2_3_x2[0][0]
# __________________________________________________________________________________________________
# conv2_3_x2 (Conv2D)             (None, 56, 56, 48)   82944       conv2_3_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_2_3 (Concatenate)        (None, 56, 56, 240)  0           concat_2_2[0][0]
#                                                                  conv2_3_x2[0][0]
# __________________________________________________________________________________________________
# conv2_4_x1_bn (BatchNormalizati (None, 56, 56, 240)  960         concat_2_3[0][0]
# __________________________________________________________________________________________________
# conv2_4_x1_scale (Scale)        (None, 56, 56, 240)  480         conv2_4_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu2_4_x1 (Activation)         (None, 56, 56, 240)  0           conv2_4_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv2_4_x1 (Conv2D)             (None, 56, 56, 192)  46080       relu2_4_x1[0][0]
# __________________________________________________________________________________________________
# conv2_4_x2_bn (BatchNormalizati (None, 56, 56, 192)  768         conv2_4_x1[0][0]
# __________________________________________________________________________________________________
# conv2_4_x2_scale (Scale)        (None, 56, 56, 192)  384         conv2_4_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu2_4_x2 (Activation)         (None, 56, 56, 192)  0           conv2_4_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv2_4_x2_zeropadding (ZeroPad (None, 58, 58, 192)  0           relu2_4_x2[0][0]
# __________________________________________________________________________________________________
# conv2_4_x2 (Conv2D)             (None, 56, 56, 48)   82944       conv2_4_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_2_4 (Concatenate)        (None, 56, 56, 288)  0           concat_2_3[0][0]
#                                                                  conv2_4_x2[0][0]
# __________________________________________________________________________________________________
# conv2_5_x1_bn (BatchNormalizati (None, 56, 56, 288)  1152        concat_2_4[0][0]
# __________________________________________________________________________________________________
# conv2_5_x1_scale (Scale)        (None, 56, 56, 288)  576         conv2_5_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu2_5_x1 (Activation)         (None, 56, 56, 288)  0           conv2_5_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv2_5_x1 (Conv2D)             (None, 56, 56, 192)  55296       relu2_5_x1[0][0]
# __________________________________________________________________________________________________
# conv2_5_x2_bn (BatchNormalizati (None, 56, 56, 192)  768         conv2_5_x1[0][0]
# __________________________________________________________________________________________________
# conv2_5_x2_scale (Scale)        (None, 56, 56, 192)  384         conv2_5_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu2_5_x2 (Activation)         (None, 56, 56, 192)  0           conv2_5_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv2_5_x2_zeropadding (ZeroPad (None, 58, 58, 192)  0           relu2_5_x2[0][0]
# __________________________________________________________________________________________________
# conv2_5_x2 (Conv2D)             (None, 56, 56, 48)   82944       conv2_5_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_2_5 (Concatenate)        (None, 56, 56, 336)  0           concat_2_4[0][0]
#                                                                  conv2_5_x2[0][0]
# __________________________________________________________________________________________________
# conv2_6_x1_bn (BatchNormalizati (None, 56, 56, 336)  1344        concat_2_5[0][0]
# __________________________________________________________________________________________________
# conv2_6_x1_scale (Scale)        (None, 56, 56, 336)  672         conv2_6_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu2_6_x1 (Activation)         (None, 56, 56, 336)  0           conv2_6_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv2_6_x1 (Conv2D)             (None, 56, 56, 192)  64512       relu2_6_x1[0][0]
# __________________________________________________________________________________________________
# conv2_6_x2_bn (BatchNormalizati (None, 56, 56, 192)  768         conv2_6_x1[0][0]
# __________________________________________________________________________________________________
# conv2_6_x2_scale (Scale)        (None, 56, 56, 192)  384         conv2_6_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu2_6_x2 (Activation)         (None, 56, 56, 192)  0           conv2_6_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv2_6_x2_zeropadding (ZeroPad (None, 58, 58, 192)  0           relu2_6_x2[0][0]
# __________________________________________________________________________________________________
# conv2_6_x2 (Conv2D)             (None, 56, 56, 48)   82944       conv2_6_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_2_6 (Concatenate)        (None, 56, 56, 384)  0           concat_2_5[0][0]
#                                                                  conv2_6_x2[0][0]
# __________________________________________________________________________________________________
# conv2_blk_bn (BatchNormalizatio (None, 56, 56, 384)  1536        concat_2_6[0][0]
# __________________________________________________________________________________________________
# conv2_blk_scale (Scale)         (None, 56, 56, 384)  768         conv2_blk_bn[0][0]
# __________________________________________________________________________________________________
# relu2_blk (Activation)          (None, 56, 56, 384)  0           conv2_blk_scale[0][0]
# __________________________________________________________________________________________________
# conv2_blk (Conv2D)              (None, 56, 56, 192)  73728       relu2_blk[0][0]
# __________________________________________________________________________________________________
# pool2 (AveragePooling2D)        (None, 28, 28, 192)  0           conv2_blk[0][0]
# __________________________________________________________________________________________________
# conv3_1_x1_bn (BatchNormalizati (None, 28, 28, 192)  768         pool2[0][0]
# __________________________________________________________________________________________________
# conv3_1_x1_scale (Scale)        (None, 28, 28, 192)  384         conv3_1_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu3_1_x1 (Activation)         (None, 28, 28, 192)  0           conv3_1_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv3_1_x1 (Conv2D)             (None, 28, 28, 192)  36864       relu3_1_x1[0][0]
# __________________________________________________________________________________________________
# conv3_1_x2_bn (BatchNormalizati (None, 28, 28, 192)  768         conv3_1_x1[0][0]
# __________________________________________________________________________________________________
# conv3_1_x2_scale (Scale)        (None, 28, 28, 192)  384         conv3_1_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu3_1_x2 (Activation)         (None, 28, 28, 192)  0           conv3_1_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv3_1_x2_zeropadding (ZeroPad (None, 30, 30, 192)  0           relu3_1_x2[0][0]
# __________________________________________________________________________________________________
# conv3_1_x2 (Conv2D)             (None, 28, 28, 48)   82944       conv3_1_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_3_1 (Concatenate)        (None, 28, 28, 240)  0           pool2[0][0]
#                                                                  conv3_1_x2[0][0]
# __________________________________________________________________________________________________
# conv3_2_x1_bn (BatchNormalizati (None, 28, 28, 240)  960         concat_3_1[0][0]
# __________________________________________________________________________________________________
# conv3_2_x1_scale (Scale)        (None, 28, 28, 240)  480         conv3_2_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu3_2_x1 (Activation)         (None, 28, 28, 240)  0           conv3_2_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv3_2_x1 (Conv2D)             (None, 28, 28, 192)  46080       relu3_2_x1[0][0]
# __________________________________________________________________________________________________
# conv3_2_x2_bn (BatchNormalizati (None, 28, 28, 192)  768         conv3_2_x1[0][0]
# __________________________________________________________________________________________________
# conv3_2_x2_scale (Scale)        (None, 28, 28, 192)  384         conv3_2_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu3_2_x2 (Activation)         (None, 28, 28, 192)  0           conv3_2_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv3_2_x2_zeropadding (ZeroPad (None, 30, 30, 192)  0           relu3_2_x2[0][0]
# __________________________________________________________________________________________________
# conv3_2_x2 (Conv2D)             (None, 28, 28, 48)   82944       conv3_2_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_3_2 (Concatenate)        (None, 28, 28, 288)  0           concat_3_1[0][0]
#                                                                  conv3_2_x2[0][0]
# __________________________________________________________________________________________________
# conv3_3_x1_bn (BatchNormalizati (None, 28, 28, 288)  1152        concat_3_2[0][0]
# __________________________________________________________________________________________________
# conv3_3_x1_scale (Scale)        (None, 28, 28, 288)  576         conv3_3_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu3_3_x1 (Activation)         (None, 28, 28, 288)  0           conv3_3_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv3_3_x1 (Conv2D)             (None, 28, 28, 192)  55296       relu3_3_x1[0][0]
# __________________________________________________________________________________________________
# conv3_3_x2_bn (BatchNormalizati (None, 28, 28, 192)  768         conv3_3_x1[0][0]
# __________________________________________________________________________________________________
# conv3_3_x2_scale (Scale)        (None, 28, 28, 192)  384         conv3_3_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu3_3_x2 (Activation)         (None, 28, 28, 192)  0           conv3_3_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv3_3_x2_zeropadding (ZeroPad (None, 30, 30, 192)  0           relu3_3_x2[0][0]
# __________________________________________________________________________________________________
# conv3_3_x2 (Conv2D)             (None, 28, 28, 48)   82944       conv3_3_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_3_3 (Concatenate)        (None, 28, 28, 336)  0           concat_3_2[0][0]
#                                                                  conv3_3_x2[0][0]
# __________________________________________________________________________________________________
# conv3_4_x1_bn (BatchNormalizati (None, 28, 28, 336)  1344        concat_3_3[0][0]
# __________________________________________________________________________________________________
# conv3_4_x1_scale (Scale)        (None, 28, 28, 336)  672         conv3_4_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu3_4_x1 (Activation)         (None, 28, 28, 336)  0           conv3_4_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv3_4_x1 (Conv2D)             (None, 28, 28, 192)  64512       relu3_4_x1[0][0]
# __________________________________________________________________________________________________
# conv3_4_x2_bn (BatchNormalizati (None, 28, 28, 192)  768         conv3_4_x1[0][0]
# __________________________________________________________________________________________________
# conv3_4_x2_scale (Scale)        (None, 28, 28, 192)  384         conv3_4_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu3_4_x2 (Activation)         (None, 28, 28, 192)  0           conv3_4_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv3_4_x2_zeropadding (ZeroPad (None, 30, 30, 192)  0           relu3_4_x2[0][0]
# __________________________________________________________________________________________________
# conv3_4_x2 (Conv2D)             (None, 28, 28, 48)   82944       conv3_4_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_3_4 (Concatenate)        (None, 28, 28, 384)  0           concat_3_3[0][0]
#                                                                  conv3_4_x2[0][0]
# __________________________________________________________________________________________________
# conv3_5_x1_bn (BatchNormalizati (None, 28, 28, 384)  1536        concat_3_4[0][0]
# __________________________________________________________________________________________________
# conv3_5_x1_scale (Scale)        (None, 28, 28, 384)  768         conv3_5_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu3_5_x1 (Activation)         (None, 28, 28, 384)  0           conv3_5_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv3_5_x1 (Conv2D)             (None, 28, 28, 192)  73728       relu3_5_x1[0][0]
# __________________________________________________________________________________________________
# conv3_5_x2_bn (BatchNormalizati (None, 28, 28, 192)  768         conv3_5_x1[0][0]
# __________________________________________________________________________________________________
# conv3_5_x2_scale (Scale)        (None, 28, 28, 192)  384         conv3_5_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu3_5_x2 (Activation)         (None, 28, 28, 192)  0           conv3_5_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv3_5_x2_zeropadding (ZeroPad (None, 30, 30, 192)  0           relu3_5_x2[0][0]
# __________________________________________________________________________________________________
# conv3_5_x2 (Conv2D)             (None, 28, 28, 48)   82944       conv3_5_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_3_5 (Concatenate)        (None, 28, 28, 432)  0           concat_3_4[0][0]
#                                                                  conv3_5_x2[0][0]
# __________________________________________________________________________________________________
# conv3_6_x1_bn (BatchNormalizati (None, 28, 28, 432)  1728        concat_3_5[0][0]
# __________________________________________________________________________________________________
# conv3_6_x1_scale (Scale)        (None, 28, 28, 432)  864         conv3_6_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu3_6_x1 (Activation)         (None, 28, 28, 432)  0           conv3_6_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv3_6_x1 (Conv2D)             (None, 28, 28, 192)  82944       relu3_6_x1[0][0]
# __________________________________________________________________________________________________
# conv3_6_x2_bn (BatchNormalizati (None, 28, 28, 192)  768         conv3_6_x1[0][0]
# __________________________________________________________________________________________________
# conv3_6_x2_scale (Scale)        (None, 28, 28, 192)  384         conv3_6_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu3_6_x2 (Activation)         (None, 28, 28, 192)  0           conv3_6_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv3_6_x2_zeropadding (ZeroPad (None, 30, 30, 192)  0           relu3_6_x2[0][0]
# __________________________________________________________________________________________________
# conv3_6_x2 (Conv2D)             (None, 28, 28, 48)   82944       conv3_6_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_3_6 (Concatenate)        (None, 28, 28, 480)  0           concat_3_5[0][0]
#                                                                  conv3_6_x2[0][0]
# __________________________________________________________________________________________________
# conv3_7_x1_bn (BatchNormalizati (None, 28, 28, 480)  1920        concat_3_6[0][0]
# __________________________________________________________________________________________________
# conv3_7_x1_scale (Scale)        (None, 28, 28, 480)  960         conv3_7_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu3_7_x1 (Activation)         (None, 28, 28, 480)  0           conv3_7_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv3_7_x1 (Conv2D)             (None, 28, 28, 192)  92160       relu3_7_x1[0][0]
# __________________________________________________________________________________________________
# conv3_7_x2_bn (BatchNormalizati (None, 28, 28, 192)  768         conv3_7_x1[0][0]
# __________________________________________________________________________________________________
# conv3_7_x2_scale (Scale)        (None, 28, 28, 192)  384         conv3_7_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu3_7_x2 (Activation)         (None, 28, 28, 192)  0           conv3_7_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv3_7_x2_zeropadding (ZeroPad (None, 30, 30, 192)  0           relu3_7_x2[0][0]
# __________________________________________________________________________________________________
# conv3_7_x2 (Conv2D)             (None, 28, 28, 48)   82944       conv3_7_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_3_7 (Concatenate)        (None, 28, 28, 528)  0           concat_3_6[0][0]
#                                                                  conv3_7_x2[0][0]
# __________________________________________________________________________________________________
# conv3_8_x1_bn (BatchNormalizati (None, 28, 28, 528)  2112        concat_3_7[0][0]
# __________________________________________________________________________________________________
# conv3_8_x1_scale (Scale)        (None, 28, 28, 528)  1056        conv3_8_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu3_8_x1 (Activation)         (None, 28, 28, 528)  0           conv3_8_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv3_8_x1 (Conv2D)             (None, 28, 28, 192)  101376      relu3_8_x1[0][0]
# __________________________________________________________________________________________________
# conv3_8_x2_bn (BatchNormalizati (None, 28, 28, 192)  768         conv3_8_x1[0][0]
# __________________________________________________________________________________________________
# conv3_8_x2_scale (Scale)        (None, 28, 28, 192)  384         conv3_8_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu3_8_x2 (Activation)         (None, 28, 28, 192)  0           conv3_8_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv3_8_x2_zeropadding (ZeroPad (None, 30, 30, 192)  0           relu3_8_x2[0][0]
# __________________________________________________________________________________________________
# conv3_8_x2 (Conv2D)             (None, 28, 28, 48)   82944       conv3_8_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_3_8 (Concatenate)        (None, 28, 28, 576)  0           concat_3_7[0][0]
#                                                                  conv3_8_x2[0][0]
# __________________________________________________________________________________________________
# conv3_9_x1_bn (BatchNormalizati (None, 28, 28, 576)  2304        concat_3_8[0][0]
# __________________________________________________________________________________________________
# conv3_9_x1_scale (Scale)        (None, 28, 28, 576)  1152        conv3_9_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu3_9_x1 (Activation)         (None, 28, 28, 576)  0           conv3_9_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv3_9_x1 (Conv2D)             (None, 28, 28, 192)  110592      relu3_9_x1[0][0]
# __________________________________________________________________________________________________
# conv3_9_x2_bn (BatchNormalizati (None, 28, 28, 192)  768         conv3_9_x1[0][0]
# __________________________________________________________________________________________________
# conv3_9_x2_scale (Scale)        (None, 28, 28, 192)  384         conv3_9_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu3_9_x2 (Activation)         (None, 28, 28, 192)  0           conv3_9_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv3_9_x2_zeropadding (ZeroPad (None, 30, 30, 192)  0           relu3_9_x2[0][0]
# __________________________________________________________________________________________________
# conv3_9_x2 (Conv2D)             (None, 28, 28, 48)   82944       conv3_9_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_3_9 (Concatenate)        (None, 28, 28, 624)  0           concat_3_8[0][0]
#                                                                  conv3_9_x2[0][0]
# __________________________________________________________________________________________________
# conv3_10_x1_bn (BatchNormalizat (None, 28, 28, 624)  2496        concat_3_9[0][0]
# __________________________________________________________________________________________________
# conv3_10_x1_scale (Scale)       (None, 28, 28, 624)  1248        conv3_10_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu3_10_x1 (Activation)        (None, 28, 28, 624)  0           conv3_10_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv3_10_x1 (Conv2D)            (None, 28, 28, 192)  119808      relu3_10_x1[0][0]
# __________________________________________________________________________________________________
# conv3_10_x2_bn (BatchNormalizat (None, 28, 28, 192)  768         conv3_10_x1[0][0]
# __________________________________________________________________________________________________
# conv3_10_x2_scale (Scale)       (None, 28, 28, 192)  384         conv3_10_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu3_10_x2 (Activation)        (None, 28, 28, 192)  0           conv3_10_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv3_10_x2_zeropadding (ZeroPa (None, 30, 30, 192)  0           relu3_10_x2[0][0]
# __________________________________________________________________________________________________
# conv3_10_x2 (Conv2D)            (None, 28, 28, 48)   82944       conv3_10_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_3_10 (Concatenate)       (None, 28, 28, 672)  0           concat_3_9[0][0]
#                                                                  conv3_10_x2[0][0]
# __________________________________________________________________________________________________
# conv3_11_x1_bn (BatchNormalizat (None, 28, 28, 672)  2688        concat_3_10[0][0]
# __________________________________________________________________________________________________
# conv3_11_x1_scale (Scale)       (None, 28, 28, 672)  1344        conv3_11_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu3_11_x1 (Activation)        (None, 28, 28, 672)  0           conv3_11_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv3_11_x1 (Conv2D)            (None, 28, 28, 192)  129024      relu3_11_x1[0][0]
# __________________________________________________________________________________________________
# conv3_11_x2_bn (BatchNormalizat (None, 28, 28, 192)  768         conv3_11_x1[0][0]
# __________________________________________________________________________________________________
# conv3_11_x2_scale (Scale)       (None, 28, 28, 192)  384         conv3_11_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu3_11_x2 (Activation)        (None, 28, 28, 192)  0           conv3_11_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv3_11_x2_zeropadding (ZeroPa (None, 30, 30, 192)  0           relu3_11_x2[0][0]
# __________________________________________________________________________________________________
# conv3_11_x2 (Conv2D)            (None, 28, 28, 48)   82944       conv3_11_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_3_11 (Concatenate)       (None, 28, 28, 720)  0           concat_3_10[0][0]
#                                                                  conv3_11_x2[0][0]
# __________________________________________________________________________________________________
# conv3_12_x1_bn (BatchNormalizat (None, 28, 28, 720)  2880        concat_3_11[0][0]
# __________________________________________________________________________________________________
# conv3_12_x1_scale (Scale)       (None, 28, 28, 720)  1440        conv3_12_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu3_12_x1 (Activation)        (None, 28, 28, 720)  0           conv3_12_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv3_12_x1 (Conv2D)            (None, 28, 28, 192)  138240      relu3_12_x1[0][0]
# __________________________________________________________________________________________________
# conv3_12_x2_bn (BatchNormalizat (None, 28, 28, 192)  768         conv3_12_x1[0][0]
# __________________________________________________________________________________________________
# conv3_12_x2_scale (Scale)       (None, 28, 28, 192)  384         conv3_12_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu3_12_x2 (Activation)        (None, 28, 28, 192)  0           conv3_12_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv3_12_x2_zeropadding (ZeroPa (None, 30, 30, 192)  0           relu3_12_x2[0][0]
# __________________________________________________________________________________________________
# conv3_12_x2 (Conv2D)            (None, 28, 28, 48)   82944       conv3_12_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_3_12 (Concatenate)       (None, 28, 28, 768)  0           concat_3_11[0][0]
#                                                                  conv3_12_x2[0][0]
# __________________________________________________________________________________________________
# conv3_blk_bn (BatchNormalizatio (None, 28, 28, 768)  3072        concat_3_12[0][0]
# __________________________________________________________________________________________________
# conv3_blk_scale (Scale)         (None, 28, 28, 768)  1536        conv3_blk_bn[0][0]
# __________________________________________________________________________________________________
# relu3_blk (Activation)          (None, 28, 28, 768)  0           conv3_blk_scale[0][0]
# __________________________________________________________________________________________________
# conv3_blk (Conv2D)              (None, 28, 28, 384)  294912      relu3_blk[0][0]
# __________________________________________________________________________________________________
# pool3 (AveragePooling2D)        (None, 14, 14, 384)  0           conv3_blk[0][0]
# __________________________________________________________________________________________________
# conv4_1_x1_bn (BatchNormalizati (None, 14, 14, 384)  1536        pool3[0][0]
# __________________________________________________________________________________________________
# conv4_1_x1_scale (Scale)        (None, 14, 14, 384)  768         conv4_1_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu4_1_x1 (Activation)         (None, 14, 14, 384)  0           conv4_1_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv4_1_x1 (Conv2D)             (None, 14, 14, 192)  73728       relu4_1_x1[0][0]
# __________________________________________________________________________________________________
# conv4_1_x2_bn (BatchNormalizati (None, 14, 14, 192)  768         conv4_1_x1[0][0]
# __________________________________________________________________________________________________
# conv4_1_x2_scale (Scale)        (None, 14, 14, 192)  384         conv4_1_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu4_1_x2 (Activation)         (None, 14, 14, 192)  0           conv4_1_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv4_1_x2_zeropadding (ZeroPad (None, 16, 16, 192)  0           relu4_1_x2[0][0]
# __________________________________________________________________________________________________
# conv4_1_x2 (Conv2D)             (None, 14, 14, 48)   82944       conv4_1_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_4_1 (Concatenate)        (None, 14, 14, 432)  0           pool3[0][0]
#                                                                  conv4_1_x2[0][0]
# __________________________________________________________________________________________________
# conv4_2_x1_bn (BatchNormalizati (None, 14, 14, 432)  1728        concat_4_1[0][0]
# __________________________________________________________________________________________________
# conv4_2_x1_scale (Scale)        (None, 14, 14, 432)  864         conv4_2_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu4_2_x1 (Activation)         (None, 14, 14, 432)  0           conv4_2_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv4_2_x1 (Conv2D)             (None, 14, 14, 192)  82944       relu4_2_x1[0][0]
# __________________________________________________________________________________________________
# conv4_2_x2_bn (BatchNormalizati (None, 14, 14, 192)  768         conv4_2_x1[0][0]
# __________________________________________________________________________________________________
# conv4_2_x2_scale (Scale)        (None, 14, 14, 192)  384         conv4_2_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu4_2_x2 (Activation)         (None, 14, 14, 192)  0           conv4_2_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv4_2_x2_zeropadding (ZeroPad (None, 16, 16, 192)  0           relu4_2_x2[0][0]
# __________________________________________________________________________________________________
# conv4_2_x2 (Conv2D)             (None, 14, 14, 48)   82944       conv4_2_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_4_2 (Concatenate)        (None, 14, 14, 480)  0           concat_4_1[0][0]
#                                                                  conv4_2_x2[0][0]
# __________________________________________________________________________________________________
# conv4_3_x1_bn (BatchNormalizati (None, 14, 14, 480)  1920        concat_4_2[0][0]
# __________________________________________________________________________________________________
# conv4_3_x1_scale (Scale)        (None, 14, 14, 480)  960         conv4_3_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu4_3_x1 (Activation)         (None, 14, 14, 480)  0           conv4_3_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv4_3_x1 (Conv2D)             (None, 14, 14, 192)  92160       relu4_3_x1[0][0]
# __________________________________________________________________________________________________
# conv4_3_x2_bn (BatchNormalizati (None, 14, 14, 192)  768         conv4_3_x1[0][0]
# __________________________________________________________________________________________________
# conv4_3_x2_scale (Scale)        (None, 14, 14, 192)  384         conv4_3_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu4_3_x2 (Activation)         (None, 14, 14, 192)  0           conv4_3_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv4_3_x2_zeropadding (ZeroPad (None, 16, 16, 192)  0           relu4_3_x2[0][0]
# __________________________________________________________________________________________________
# conv4_3_x2 (Conv2D)             (None, 14, 14, 48)   82944       conv4_3_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_4_3 (Concatenate)        (None, 14, 14, 528)  0           concat_4_2[0][0]
#                                                                  conv4_3_x2[0][0]
# __________________________________________________________________________________________________
# conv4_4_x1_bn (BatchNormalizati (None, 14, 14, 528)  2112        concat_4_3[0][0]
# ...
# __________________________________________________________________________________________________
# conv5_18_x1_scale (Scale)       (None, 7, 7, 1872)   3744        conv5_18_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu5_18_x1 (Activation)        (None, 7, 7, 1872)   0           conv5_18_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv5_18_x1 (Conv2D)            (None, 7, 7, 192)    359424      relu5_18_x1[0][0]
# __________________________________________________________________________________________________
# conv5_18_x2_bn (BatchNormalizat (None, 7, 7, 192)    768         conv5_18_x1[0][0]
# __________________________________________________________________________________________________
# conv5_18_x2_scale (Scale)       (None, 7, 7, 192)    384         conv5_18_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu5_18_x2 (Activation)        (None, 7, 7, 192)    0           conv5_18_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv5_18_x2_zeropadding (ZeroPa (None, 9, 9, 192)    0           relu5_18_x2[0][0]
# __________________________________________________________________________________________________
# conv5_18_x2 (Conv2D)            (None, 7, 7, 48)     82944       conv5_18_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_5_18 (Concatenate)       (None, 7, 7, 1920)   0           concat_5_17[0][0]
#                                                                  conv5_18_x2[0][0]
# __________________________________________________________________________________________________
# conv5_19_x1_bn (BatchNormalizat (None, 7, 7, 1920)   7680        concat_5_18[0][0]
# __________________________________________________________________________________________________
# conv5_19_x1_scale (Scale)       (None, 7, 7, 1920)   3840        conv5_19_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu5_19_x1 (Activation)        (None, 7, 7, 1920)   0           conv5_19_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv5_19_x1 (Conv2D)            (None, 7, 7, 192)    368640      relu5_19_x1[0][0]
# __________________________________________________________________________________________________
# conv5_19_x2_bn (BatchNormalizat (None, 7, 7, 192)    768         conv5_19_x1[0][0]
# __________________________________________________________________________________________________
# conv5_19_x2_scale (Scale)       (None, 7, 7, 192)    384         conv5_19_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu5_19_x2 (Activation)        (None, 7, 7, 192)    0           conv5_19_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv5_19_x2_zeropadding (ZeroPa (None, 9, 9, 192)    0           relu5_19_x2[0][0]
# __________________________________________________________________________________________________
# conv5_19_x2 (Conv2D)            (None, 7, 7, 48)     82944       conv5_19_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_5_19 (Concatenate)       (None, 7, 7, 1968)   0           concat_5_18[0][0]
#                                                                  conv5_19_x2[0][0]
# __________________________________________________________________________________________________
# conv5_20_x1_bn (BatchNormalizat (None, 7, 7, 1968)   7872        concat_5_19[0][0]
# __________________________________________________________________________________________________
# conv5_20_x1_scale (Scale)       (None, 7, 7, 1968)   3936        conv5_20_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu5_20_x1 (Activation)        (None, 7, 7, 1968)   0           conv5_20_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv5_20_x1 (Conv2D)            (None, 7, 7, 192)    377856      relu5_20_x1[0][0]
# __________________________________________________________________________________________________
# conv5_20_x2_bn (BatchNormalizat (None, 7, 7, 192)    768         conv5_20_x1[0][0]
# __________________________________________________________________________________________________
# conv5_20_x2_scale (Scale)       (None, 7, 7, 192)    384         conv5_20_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu5_20_x2 (Activation)        (None, 7, 7, 192)    0           conv5_20_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv5_20_x2_zeropadding (ZeroPa (None, 9, 9, 192)    0           relu5_20_x2[0][0]
# __________________________________________________________________________________________________
# conv5_20_x2 (Conv2D)            (None, 7, 7, 48)     82944       conv5_20_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_5_20 (Concatenate)       (None, 7, 7, 2016)   0           concat_5_19[0][0]
#                                                                  conv5_20_x2[0][0]
# __________________________________________________________________________________________________
# conv5_21_x1_bn (BatchNormalizat (None, 7, 7, 2016)   8064        concat_5_20[0][0]
# __________________________________________________________________________________________________
# conv5_21_x1_scale (Scale)       (None, 7, 7, 2016)   4032        conv5_21_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu5_21_x1 (Activation)        (None, 7, 7, 2016)   0           conv5_21_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv5_21_x1 (Conv2D)            (None, 7, 7, 192)    387072      relu5_21_x1[0][0]
# __________________________________________________________________________________________________
# conv5_21_x2_bn (BatchNormalizat (None, 7, 7, 192)    768         conv5_21_x1[0][0]
# __________________________________________________________________________________________________
# conv5_21_x2_scale (Scale)       (None, 7, 7, 192)    384         conv5_21_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu5_21_x2 (Activation)        (None, 7, 7, 192)    0           conv5_21_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv5_21_x2_zeropadding (ZeroPa (None, 9, 9, 192)    0           relu5_21_x2[0][0]
# __________________________________________________________________________________________________
# conv5_21_x2 (Conv2D)            (None, 7, 7, 48)     82944       conv5_21_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_5_21 (Concatenate)       (None, 7, 7, 2064)   0           concat_5_20[0][0]
#                                                                  conv5_21_x2[0][0]
# __________________________________________________________________________________________________
# conv5_22_x1_bn (BatchNormalizat (None, 7, 7, 2064)   8256        concat_5_21[0][0]
# __________________________________________________________________________________________________
# conv5_22_x1_scale (Scale)       (None, 7, 7, 2064)   4128        conv5_22_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu5_22_x1 (Activation)        (None, 7, 7, 2064)   0           conv5_22_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv5_22_x1 (Conv2D)            (None, 7, 7, 192)    396288      relu5_22_x1[0][0]
# __________________________________________________________________________________________________
# conv5_22_x2_bn (BatchNormalizat (None, 7, 7, 192)    768         conv5_22_x1[0][0]
# __________________________________________________________________________________________________
# conv5_22_x2_scale (Scale)       (None, 7, 7, 192)    384         conv5_22_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu5_22_x2 (Activation)        (None, 7, 7, 192)    0           conv5_22_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv5_22_x2_zeropadding (ZeroPa (None, 9, 9, 192)    0           relu5_22_x2[0][0]
# __________________________________________________________________________________________________
# conv5_22_x2 (Conv2D)            (None, 7, 7, 48)     82944       conv5_22_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_5_22 (Concatenate)       (None, 7, 7, 2112)   0           concat_5_21[0][0]
#                                                                  conv5_22_x2[0][0]
# __________________________________________________________________________________________________
# conv5_23_x1_bn (BatchNormalizat (None, 7, 7, 2112)   8448        concat_5_22[0][0]
# __________________________________________________________________________________________________
# conv5_23_x1_scale (Scale)       (None, 7, 7, 2112)   4224        conv5_23_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu5_23_x1 (Activation)        (None, 7, 7, 2112)   0           conv5_23_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv5_23_x1 (Conv2D)            (None, 7, 7, 192)    405504      relu5_23_x1[0][0]
# __________________________________________________________________________________________________
# conv5_23_x2_bn (BatchNormalizat (None, 7, 7, 192)    768         conv5_23_x1[0][0]
# __________________________________________________________________________________________________
# conv5_23_x2_scale (Scale)       (None, 7, 7, 192)    384         conv5_23_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu5_23_x2 (Activation)        (None, 7, 7, 192)    0           conv5_23_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv5_23_x2_zeropadding (ZeroPa (None, 9, 9, 192)    0           relu5_23_x2[0][0]
# __________________________________________________________________________________________________
# conv5_23_x2 (Conv2D)            (None, 7, 7, 48)     82944       conv5_23_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_5_23 (Concatenate)       (None, 7, 7, 2160)   0           concat_5_22[0][0]
#                                                                  conv5_23_x2[0][0]
# __________________________________________________________________________________________________
# conv5_24_x1_bn (BatchNormalizat (None, 7, 7, 2160)   8640        concat_5_23[0][0]
# __________________________________________________________________________________________________
# conv5_24_x1_scale (Scale)       (None, 7, 7, 2160)   4320        conv5_24_x1_bn[0][0]
# __________________________________________________________________________________________________
# relu5_24_x1 (Activation)        (None, 7, 7, 2160)   0           conv5_24_x1_scale[0][0]
# __________________________________________________________________________________________________
# conv5_24_x1 (Conv2D)            (None, 7, 7, 192)    414720      relu5_24_x1[0][0]
# __________________________________________________________________________________________________
# conv5_24_x2_bn (BatchNormalizat (None, 7, 7, 192)    768         conv5_24_x1[0][0]
# __________________________________________________________________________________________________
# conv5_24_x2_scale (Scale)       (None, 7, 7, 192)    384         conv5_24_x2_bn[0][0]
# __________________________________________________________________________________________________
# relu5_24_x2 (Activation)        (None, 7, 7, 192)    0           conv5_24_x2_scale[0][0]
# __________________________________________________________________________________________________
# conv5_24_x2_zeropadding (ZeroPa (None, 9, 9, 192)    0           relu5_24_x2[0][0]
# __________________________________________________________________________________________________
# conv5_24_x2 (Conv2D)            (None, 7, 7, 48)     82944       conv5_24_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concat_5_24 (Concatenate)       (None, 7, 7, 2208)   0           concat_5_23[0][0]
#                                                                  conv5_24_x2[0][0]
# __________________________________________________________________________________________________
# conv5_blk_bn (BatchNormalizatio (None, 7, 7, 2208)   8832        concat_5_24[0][0]
# __________________________________________________________________________________________________
# conv5_blk_scale (Scale)         (None, 7, 7, 2208)   4416        conv5_blk_bn[0][0]
# __________________________________________________________________________________________________
# relu5_blk (Activation)          (None, 7, 7, 2208)   0           conv5_blk_scale[0][0]
# __________________________________________________________________________________________________
# pool5 (GlobalAveragePooling2D)  (None, 2208)         0           relu5_blk[0][0]
# __________________________________________________________________________________________________
# fc6 (Dense)                     (None, 2019)         4459971     pool5[0][0]
# __________________________________________________________________________________________________
# prob (Activation)               (None, 2019)         0           fc6[0][0]
# ==================================================================================================
# Total params: 31,371,843
# Trainable params: 31,151,907
# Non-trainable params: 219,936
# __________________________________________________________________________________________________
# ----------------------------------------------------------------------------------------------------

# %%
weights_path="./models/densenet161_newtrain3/imaterialist-e01-1.6757.hd5"
densenet161_predict_model.load_weights(weights_path)

# %%
validate_val_dataset(densenet161_predict_model)
# Out:
# Found 10095 images belonging to 2019 classes.
# 631/631 [==============================] - 96s 152ms/step
# [1.6756566318443, 0.5551263001840147]
# [1.6756566318443, 0.5551263001840147]

# %%
test_data_generator = DataGenerator(file_type='predict', corp=True, batch_size=batch_size, shuffle=False)
# Out:
# Found 90833 images belonging to 1 classes.

# %%
densenet161_filenames, densenet161_pred = predict(densenet161_predict_model, test_data_generator)
# Out:
# 5678/5678 [==============================] - 735s 130ms/step

# %%
import os
directory = "./submissions/middle/densenet161_newtrain3/imaterialist-e01-1.6757"
os.makedirs(directory)
np.save(directory+"/densenet161_pred.npy",densenet161_pred)
np.save(directory+"/densenet161_filenames.npy",densenet161_filenames)

# %% [markdown]
# ## 融合模型答案

# %%
import numpy as np
import pandas as pd

# %%
a_dir = "./submissions/middle/densenet161/imaterialist-e01-1.8250"
a_filenames = np.load(a_dir+"/densenet161_filenames.npy")
a_predictions = np.load(a_dir+"/densenet161_pred.npy")


# b_dir = "./submissions/middle/densenet161_newtrain2/imaterialist-e01-1.6591"
b_dir = "./submissions/middle/densenet161_newtrain3/imaterialist-e01-1.6757"
b_filenames = np.load(b_dir+"/densenet161_filenames.npy")
b_predictions = np.load(b_dir+"/densenet161_pred.npy")

c_dir = "./submissions/middle/resnet152/imaterialist-e01-2.1856"
c_filenames = np.load(c_dir+"/resnet152_filenames.npy")
c_predictions = np.load(c_dir+"/resnet152_pred.npy")

d_dir = "./submissions/middle/resnet152/imaterialist-e01-2.3851"
d_filenames = np.load(d_dir+"/resnet152_filenames.npy")
d_predictions = np.load(d_dir+"/resnet152_pred.npy")

# %%
print(len(a_filenames))
# Out:
# 90833

# %%
answer = a_filenames == b_filenames

# %%
for each in answer:
    if each != True:
        print(each)

# %%
answer = a_filenames == c_filenames
for each in answer:
    if each != True:
        print(each)

# %%
answer = a_filenames == d_filenames
for each in answer:
    if each != True:
        print(each)

# %% [markdown]
# ### 1. 直接相加

# %%
new_pred = a_predictions + b_predictions
new_pred_temp = a_predictions + b_predictions

# %%
new_pred = a_predictions + b_predictions + c_predictions + d_predictions

# %%
print(sum(new_pred[0]))
# Out:
# 3.9999999021615826

# %% [markdown]
# ### 2. 取topN相加

# %%
def get_topN(pred, N):
    import copy
    idx_list = []
    prediction = copy.deepcopy(pred)
    for i in range(N):
        pos = prediction.argmax()
        idx_list.append(pos)
        prediction[pos] = -1
    return idx_list

# %%
def mixTopN(pred_a, pred_b, N):
    new_pred = np.zeros(2019, dtype=float)
    a_idx = get_topN(pred_a, N)
    b_idx = get_topN(pred_b, N)
    for i in range(N):
        new_pred[a_idx[i]] = new_pred[a_idx[i]] + pred_a[a_idx[i]]
        new_pred[b_idx[i]] = new_pred[b_idx[i]] + pred_b[b_idx[i]]
    return new_pred

# %%
new_pred = []
for idx in range(len(a_filenames)):
    tmp = mixTopN(new_pred_temp[idx], c_predictions[idx], 5)
    new_pred.append(tmp)

# %%
print(sum(new_pred[0]))
# Out:
# 0.818539647385478

# %% [markdown]
# ## top3获取并且包装为 csv 格式

# %%
import copy

# %%
predictions = copy.deepcopy(densenet161_pred)
filenames = copy.deepcopy(densenet161_filenames)

# %%
predictions = copy.deepcopy(new_pred)
filenames = copy.deepcopy(a_filenames)

# %%
top3=[]
top3_cnt = 0
for idx in range(len(filenames)):
    predict = copy.deepcopy(predictions[idx])
    temp = []
    for j in range(3):
        pos = predict.argmax()
        temp.append(str(pos))
        predict[pos]=-1
    image_id = filenames[idx].split('/')[-1]
    top3.append([image_id, ' '.join(temp)])

# %%
print(len(top3))
# Out:
# 90833

# %%
top3.append(["e156a54a448d0e120593bbe1e50470f5.jpg", "0 1 2"])

# %%
import csv
submission_filename = "./submissions/submission_0602_result_4.csv"
headers=['id', 'predicted']
result = top3
with open(submission_filename, "w", newline='') as csvfile:
    writer  = csv.writer(csvfile)
    writer.writerow(headers)
    for row in result:
        writer.writerow(row)

# %%
import csv
import re

pattern = re.compile("\\d{1,}\ \\d{1,}\ \\d{1,}")  # 'int int int'的格式

check_flag = True

NUM_TEST = 90834

with open(submission_filename) as csvfile:
    print(submission_filename)
    csv_reader = csv.reader(csvfile)
    header = next(csv_reader)
    
    # judge the header
    if(header == ['id', 'predicted']):
        print("Header is right.")
    else:
        check_flag = False
        print("Wrong header:", header)
        print("Accepted header is ['id', 'predicted']")
    
    #judege each answer
    cnt = 0
    for each in csv_reader:
        cnt = cnt+1
        if len(each) != 2:
            check_flag = False
            print("Accepted result is [id, class]")
        if not pattern.match(each[-1]):
            check_flag = False
            print(cnt)
            print(each)
            print("Wrong result format:", each[-1])
            
    if(NUM_TEST != cnt):
        check_flag = False
        print("Wrong number of submission file.")
        
    if check_flag:
        print("You can submit the result")
    else:
        print("!!! Check the result again")
# Out:
# ./submissions/submission_0602_result_4.csv
# Header is right.
# You can submit the result
