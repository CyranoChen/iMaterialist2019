# %%
from lib.KerasImageGenerator import *

import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
Image_Keras_Generator = KerasImageGenerator(ds='val',corp = True,batch_size = 16)
# Out:
# Found 10095 images belonging to 2019 classes.

# %%
image_generator_Iterator = Image_Keras_Generator.keras_get_images_iter()

# %%
x_batch, y_batch = image_generator_Iterator.next()
print(y_batch.shape)
print(x_batch.shape)
for i in range(16):
    plt.imshow(x_batch[i])
    plt.show()
# Out:
# (16, 2019)
# (16, 224, 224, 3)
