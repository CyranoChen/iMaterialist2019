# %%
from lib.ImageGenerator import *


import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
Image_Generator = ImageGenerator()

# %%
image_id = 'if len(res)>0 and res != [['<blank>']]:'
try:
    image = Image_Generator.get_image_by_id(img_id=image_id,ds='val')
except:
    print('error')
print(image.shape)
import matplotlib.pyplot as plt
plt.imshow(image)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-88c762d4f789> in <module>
# ----> 1 image_id = 'if len(res)>0 and res != [['<blank>']]:'
#       2 try:
#       3     image = Image_Generator.get_image_by_id(img_id=image_id,ds='val')
#       4 except:
#       5     print('error')
#
# NameError: name 'blank' is not defined

# %%
image_id = '90d4396de974f9c5a714d17f0a8c3749.jpg'
try:
    image = Image_Generator.get_image_by_id(img_id=image_id,ds='val',width = 255,height=255)
except:
    print('error')
print(image.shape)
import matplotlib.pyplot as plt
plt.imshow(image)
# Out:
# (255, 255, 3)

# %%
image_id = '90d4396de974f9c5a714d17f0a8c3749.jpg'
try:
    image = Image_Generator.get_image_by_id_generator(img_id=image_id,ds='val',width = 255,height=255)
except:
    print('error')
print(image.shape)
# Out:
# (1, 255, 255, 3)

# %%
class_id = 10
try:
    image = Image_Generator.get_images_by_class(class_id=class_id,ds='val',width = 255,height=255)
except:
    print('error')

# %%
class_id = 10
try:
    image = Image_Generator.get_images_by_class(class_id=class_id,ds='val',width = 255,height=255)
except:
    print('error')

# %%
#default  width = 255 height = 99   if you put  width = 0 height = 0 then return a list of former picture
class_id = 780
try:
    images, ids = Image_Generator.get_images_by_class(class_id=class_id, ds='val',width = 255,height=255)
except:
    print('error')
print(type(images))

import matplotlib.pyplot as plt

for i in range(len(ids)):
    print(ids[i])
    plt.imshow(images[i])
    plt.show()
# Out:
# <class 'numpy.ndarray'>
# 8cc640c9b71e6d9a07800dfb18b9b65a.jpg
# 9fc0fae1bac8b22344c510778b91b6e8.jpg
# a125fb05d8eceebf6e3b6ddc52558e4e.jpg
# 58942e786df4efbaf255fa1e1ceeb932.jpg
# ea01aec93b89a9d96521b4b98f9821e1.jpg

# %%
#default  width = 255 height = 99   if you put  width = 0 height = 0 then return a list of former picture
class_id = 781
try:
    images, ids = Image_Generator.get_images_by_class(class_id=class_id, ds='val',width = 255,height=255)
except:
    print('error')
print(type(images))

import matplotlib.pyplot as plt

for i in range(len(ids)):
    print(ids[i])
    plt.imshow(images[i])
    plt.show()
# Out:
# <class 'numpy.ndarray'>
# 89f283d6e351059b0c59429808e659c3.jpg
# 5d4fd93af799166da948d7247508930c.jpg
# bd14ee2fea2bcd37b63936bdcbef3210.png
# 346c0e90cc78dc62f4d15f7b386fa22f.jpg
# 51c83e4107fb783b62bff6035f965c50.jpg

# %%
#default  width = 255 height = 99   if you put  width = 0 height = 0 then return a list of former picture
class_id = 2018
try:
    images, ids = Image_Generator.get_images_by_class(class_id=class_id, ds='val',width = 255,height=255)
except:
    print('error')
print(type(images))

import matplotlib.pyplot as plt

for i in range(len(ids)):
    print(ids[i])
    plt.imshow(images[i])
    plt.show()
# Out:
# <class 'numpy.ndarray'>
# 8e2d9df30e687b95b17f7aba074dd77a.jpg
# 1fbc219cd873b8ea0cf114c17874ecca.jpg
# 5aff27869fdbe9884bb65c895e21808b.jpg
# e930a8d3830d83056515f9889ea1e00f.jpg
# aa97b136b45a1f8bc208c5612da5ee18.jpg

# %%
#default  width = 255 height = 99   if you put  width = 0 height = 0 then return a list of former picture
class_id = 10
try:
    image, ids = Image_Generator.get_images_by_class(class_id=class_id,ds='train',width = 255,height=255)
except:
    print('error')
print(type(image))
import matplotlib.pyplot as plt
plt.imshow(image[0])
# Out:
# (400, 400, 3)
# (160, 160, 3)
# (750, 750, 3)
# (800, 800, 3)
# (800, 800, 3)
# (709, 709, 3)
# (256, 256, 3)
# (800, 800, 3)
# (563, 563, 3)
# (724, 724, 3)
# (1080, 1080, 3)
# (750, 750, 3)
# (406, 406, 3)
# (320, 320, 3)
# (800, 800, 3)
# (800, 800, 3)
# (300, 300, 3)
# (350, 350, 3)
# (800, 800, 3)
# (1080, 1080, 3)
# (810, 810, 3)
# (640, 640, 3)
# (839, 839, 3)
# (744, 744, 3)
# (750, 750, 3)
# (800, 800, 3)
# (666, 666, 3)
# (640, 640, 3)
# (750, 750, 3)
# (756, 756, 3)
# (389, 389, 3)
# (357, 357, 3)
# (640, 640, 3)
# (643, 643, 3)
# (640, 640, 3)
# (350, 350, 3)
# (360, 360, 3)
# (160, 160, 3)
# (720, 720, 3)
# (720, 720, 3)
# (427, 427, 3)
# (864, 864, 3)
# (260, 260, 3)
# (800, 800, 3)
# (640, 640, 3)
# (790, 790, 3)
# (1000, 1000, 3)
# (800, 800, 3)
# (256, 256, 3)
# (800, 800, 3)
# (750, 750, 3)
# (640, 640, 3)
# (800, 800, 3)
# (750, 750, 3)
# (640, 640, 3)
# (422, 422, 3)
# (800, 800, 3)
# (1080, 1080, 3)
# (640, 640, 3)
# (800, 800, 3)
# (506, 506, 3)
# (600, 600, 3)
# ...
